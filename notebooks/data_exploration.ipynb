# %% [markdown]
# # Data Exploraiton and Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
data = pd.read_csv('../data/dummy_company_data.csv')

# %%
data
# Out:
#   Company_Name                Sector  EPS   P_E  P_B  Dividend_Yield  ROA  \
# 0        BankA       Commercial Bank  3.5  12.5  1.2             4.2  1.5
# 1       HydroB            Hydropower  2.8  15.0  1.5             3.8  1.2
# 2       HotelC     Hotel and Tourism  1.5  18.0  2.0             2.5  0.8
# 3   DebentureD  Corporate Debentures  4.0  10.0  0.9             5.0  2.0
# 4     FinanceE               Finance  2.2  14.0  1.3             3.5  1.0
# 5        BondF      Government Bonds  3.0   8.0  0.7             6.0  2.5
# 6      InvestG            Investment  2.5  16.0  1.8             3.0  1.3
# 7        LifeH        Life Insurance  3.2  13.0  1.4             4.0  1.7
# 8       TradeI               Trading  1.8  17.0  2.1             2.8  0.9
# 9        ManuJ         Manufacturing  2.7  15.5  1.6             3.7  1.4
#
#     ROE  Debt_to_Equity  Price_Momentum  Volume_Trends  Ownership_Pattern  \
# 0  12.0             0.8            0.05           0.03               0.70
# 1  10.5             1.0            0.02           0.01               0.60
# 2   8.0             1.2           -0.01           0.02               0.50
# 3  15.0             0.5            0.04           0.04               0.80
# 4   9.0             0.9            0.03           0.02               0.65
# 5  18.0             0.3            0.01           0.01               0.90
# 6  11.0             1.1            0.02           0.03               0.55
# 7  13.0             0.7            0.04           0.02               0.75
# 8   7.5             1.3           -0.02           0.01               0.50
# 9  10.0             1.0            0.03           0.03               0.60
#
#    Regulatory_Red_Flags
# 0                     0
# 1                     1
# 2                     0
# 3                     0
# 4                     1
# 5                     0
# 6                     0
# 7                     0
# 8                     1
# 9                     0

# %%
print(data.describe())
# Out:
#              EPS        P_E        P_B  Dividend_Yield       ROA        ROE  \
# count  10.000000  10.000000  10.000000       10.000000  10.00000  10.000000
# mean    2.720000  13.900000   1.450000        3.850000   1.43000  11.400000
# std     0.761285   3.116266   0.450309        1.048014   0.52504   3.247221
# min     1.500000   8.000000   0.700000        2.500000   0.80000   7.500000
# 25%     2.275000  12.625000   1.225000        3.125000   1.05000   9.250000
# 50%     2.750000  14.500000   1.450000        3.750000   1.35000  10.750000
# 75%     3.150000  15.875000   1.750000        4.150000   1.65000  12.750000
# max     4.000000  18.000000   2.100000        6.000000   2.50000  18.000000
#
#        Debt_to_Equity  Price_Momentum  Volume_Trends  Ownership_Pattern  \
# count       10.000000       10.000000      10.000000          10.000000
# mean         0.880000        0.021000       0.022000           0.655000
# std          0.311983        0.022336       0.010328           0.132183
# min          0.300000       -0.020000       0.010000           0.500000
# 25%          0.725000        0.012500       0.012500           0.562500
# 50%          0.950000        0.025000       0.020000           0.625000
# 75%          1.075000        0.037500       0.030000           0.737500
# max          1.300000        0.050000       0.040000           0.900000
#
#        Regulatory_Red_Flags
# count             10.000000
# mean               0.300000
# std                0.483046
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.750000
# max                1.000000

# %%
# Sector distribution
plt.figure(figsize=(10, 6))
sns.countplot(y='Sector', data=data)
plt.title('Distribution of Companies by Sector')
plt.savefig('sector_distribution.png')

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation of Financial Metrics')
plt.savefig('correlation_heatmap.png')

# %%
# Distribution of EPS
plt.figure(figsize=(8, 6))
sns.histplot(data['EPS'], bins=20)
plt.title('EPS Distribution')
plt.savefig('eps_distribution.png')
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
